# %%
import matplotlib.pyplot as plt 
import numpy as np 
import networkx as nx 
import pandas as pd

# %%
a = np.load("./a.npy")
u = np.load("./u.npy")
b = np.load("./b.npy")

# %%
disease = pd.DataFrame(pd.read_csv('disease.csv'))
disease
# Out:
#     id    lb                                               desc
# 0    0   001                  infectious and parasitic diseases
# 1    1   140                                          neoplasms
# 2    2   240                                 metabolic diseases
# 3    3   280     diseases of the blood and blood-forming organs
# 4    4   290                                   mental disorders
# 5    5   320                                 neurologic disease
# 6    6   390                              acute rheumatic fever
# 7    7   393                    chronic rheumatic heart disease
# 8    8   401                               hypertensive disease
# 9    9   410                             ischemic heart disease
# 10  10   415                  diseases of pulmonary circulation
# 11  11   428                                      heart failure
# 12  12   420                       other forms of heart disease
# 13  13   430                            cerebrovascular disease
# 14  14   440                                 arteries and veins
# 15  15   460                                  pulmonary disease
# 16  16   520                                  digestive disease
# 17  17   580                                renal insufficiency
# 18  18   630  Complications of pregnancy, childbirth, and th...
# 19  19   680       diseases of the skin and subcutaneous tissue
# 20  20   710  diseases of the musculoskeletal system & conne...
# 21  21   740                               congenital anomalies
# 22  22   780        symptoms, signs, and ill-defined conditions
# 23  23   800                                             trauma
# 24  24   960                                          poisoning
# 25  25   990   other and unspecified effects of external causes
# 26  26   996  complications peculiar to certain specified pr...
# 27  27   997  complications affecting specified body systems...
# 28  28   998             other complications of procedures, NEC
# 29  29   999  complications of medical care, not elsewhere c...
# 30  30  E800  supplementary classification of external cause...
# 31  31   V81  supplementary classification of factors influe...

# %%
# %matplotlib inline 

plt.imshow(a)

# %%
plt.imshow(u)

# %%
b
# Out:
# array(7.92308799)

# %%
Graphs = []

for i in range(a.shape[0]):
    Gi = nx.DiGraph()
    for j in range(a.shape[1]):
        if a[j][i] > 0.03: 
            Gi.add_edge(i, j, weight=a[j][i])
        
    Graphs.append(Gi)

# %%
def draw(G):
    edges = G.edges()
    weights = [G[u][v]['weight'] for u, v in edges]

    nx.draw(
        G,
        nx.layout.spring_layout(G),
        edges=edges,
        width=2,
        edge_color=weights,
        node_color='#D88D8D',
        edge_cmap=plt.cm.RdPu,
        with_labels=True,
        arrowstyle='->',
        arrowsize=10,
    )

# %%
draw(Graphs[0])

# %%
draw(Graphs[1])

# %%
G = nx.DiGraph()

# %%
for i in range(a.shape[0]):
    for j in range(a.shape[1]):
        if a[i][j] > 0.01 and i != j:
            G.add_edge(j, i, weight=np.log(a[i][j]))

# %%
# pos = nx.spring_layout(G, k=20)

edges = G.edges()
weights = [G[u][v]['weight'] for u, v in edges]

# %%
nx.draw(
    G,
    nx.layout.spring_layout(G),
    edges=edges,
    width=2,
    edge_color=weights,
    node_color='#D88D8D',
    edge_cmap=plt.cm.RdPu,
    with_labels=True,
    arrowstyle='->',
    arrowsize=10,
)
